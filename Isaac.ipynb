# %%
pip install pandas

# %%
import pandas as pd

# %%
import html5lib

# %%
f_states = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')

# %% [markdown]
# # importação de tabela em site wikipédia...**negrito**

# %%
from pandas.io.html import read_html
read_html
# Out:
# <function pandas.io.html.read_html(io: 'FilePath | ReadBuffer[str]', *, match: 'str | Pattern' = '.+', flavor: 'str | None' = None, header: 'int | Sequence[int] | None' = None, index_col: 'int | Sequence[int] | None' = None, skiprows: 'int | Sequence[int] | slice | None' = None, attrs: 'dict[str, str] | None' = None, parse_dates: 'bool' = False, thousands: 'str | None' = ',', encoding: 'str | None' = None, decimal: 'str' = '.', converters: 'dict | None' = None, na_values: 'Iterable[object] | None' = None, keep_default_na: 'bool' = True, displayed_only: 'bool' = True, extract_links: "Literal[None, 'header', 'footer', 'body', 'all']" = None) -> 'list[DataFrame]'>

# %% [markdown]
# # varre o código HTML inteiro da página em busca de tabelas e as adiciona a uma lista

# %%
df_list = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')

# %%
df_list = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %%
read_html
# Out:
# <function pandas.io.html.read_html(io: 'FilePath | ReadBuffer[str]', *, match: 'str | Pattern' = '.+', flavor: 'str | None' = None, header: 'int | Sequence[int] | None' = None, index_col: 'int | Sequence[int] | None' = None, skiprows: 'int | Sequence[int] | slice | None' = None, attrs: 'dict[str, str] | None' = None, parse_dates: 'bool' = False, thousands: 'str | None' = ',', encoding: 'str | None' = None, decimal: 'str' = '.', converters: 'dict | None' = None, na_values: 'Iterable[object] | None' = None, keep_default_na: 'bool' = True, displayed_only: 'bool' = True, extract_links: "Literal[None, 'header', 'footer', 'body', 'all']" = None) -> 'list[DataFrame]'>

# %%
df_list[0].head()
# Out:
#               Bank NameBank       CityCity StateSt  CertCert  \
# 0  Heartland Tri-State Bank        Elkhart      KS     25851
# 1       First Republic Bank  San Francisco      CA     59017
# 2            Signature Bank       New York      NY     57053
# 3       Silicon Valley Bank    Santa Clara      CA     24735
# 4         Almena State Bank         Almena      KS     15426
#
#                Acquiring InstitutionAI Closing DateClosing  FundFund
# 0               Dream First Bank, N.A.       July 28, 2023     10544
# 1            JPMorgan Chase Bank, N.A.         May 1, 2023     10543
# 2                  Flagstar Bank, N.A.      March 12, 2023     10540
# 3  First–Citizens Bank & Trust Company      March 10, 2023     10539
# 4                          Equity Bank    October 23, 2020     10538

# %%
df =pd.read_html('https://gist.github.com/armgilles/194bcff35001e7eb53a2a8b441e8b2c6')[0]

# %%
df
# Out:
#      Unnamed: 0    #                   Name   Type 1  Type 2  Total  HP  \
# 0           NaN    1              Bulbasaur    Grass  Poison    318  45
# 1           NaN    2                Ivysaur    Grass  Poison    405  60
# 2           NaN    3               Venusaur    Grass  Poison    525  80
# 3           NaN    3  VenusaurMega Venusaur    Grass  Poison    625  80
# 4           NaN    4             Charmander     Fire     NaN    309  39
# ..          ...  ...                    ...      ...     ...    ...  ..
# 795         NaN  719                Diancie     Rock   Fairy    600  50
# 796         NaN  719    DiancieMega Diancie     Rock   Fairy    700  50
# 797         NaN  720    HoopaHoopa Confined  Psychic   Ghost    600  80
# 798         NaN  720     HoopaHoopa Unbound  Psychic    Dark    680  80
# 799         NaN  721              Volcanion     Fire   Water    600  80
#
#      Attack  Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
coluna = df['Name']

# %% [markdown]
# # selecionando uma coluna do DataFrame.

# %%
colunas = df[['Name','Type 1','Attack']]

# %% [markdown]
# # selecionando várias colunas do DataFrame

# %%
linhas = df[df['Attack'] > 100]

# %% [markdown]
# # selecionando linhas do DataFrame com base emcondições, ex >, <, <=, >=, ==.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  0 non-null      float64
#  1   #           800 non-null    int64
#  2   Name        800 non-null    object
#  3   Type 1      800 non-null    object
#  4   Type 2      414 non-null    object
#  5   Total       800 non-null    int64
#  6   HP          800 non-null    int64
#  7   Attack      800 non-null    int64
#  8   Defense     800 non-null    int64
#  9   Sp. Atk     800 non-null    int64
#  10  Sp. Def     800 non-null    int64
#  11  Speed       800 non-null    int64
#  12  Generation  800 non-null    int64
#  13  Legendary   800 non-null    bool
# dtypes: bool(1), float64(1), int64(9), object(3)
# memory usage: 82.2+ KB

# %%
df.tail()
# Out:
#      Unnamed: 0    #                 Name   Type 1 Type 2  Total  HP  Attack  \
# 795         NaN  719              Diancie     Rock  Fairy    600  50     100
# 796         NaN  719  DiancieMega Diancie     Rock  Fairy    700  50     160
# 797         NaN  720  HoopaHoopa Confined  Psychic  Ghost    600  80     110
# 798         NaN  720   HoopaHoopa Unbound  Psychic   Dark    680  80     160
# 799         NaN  721            Volcanion     Fire  Water    600  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 795      150      100      150     50           6       True
# 796      110      160      110    110           6       True
# 797       60      150      130     70           6       True
# 798       60      170      130     80           6       True
# 799      120      130       90     70           6       True

# %% [markdown]
# # Inspecionando a base

# %%
df.shape
# Out:
# (800, 14)

# %%
df[(df["Attack"] >= 80) & (df["Defense"] >= 150)]
# Out:
#      Unnamed: 0    #                     Name  Type 1   Type 2  Total   HP  \
# 98          NaN   91                 Cloyster   Water      Ice    525   50
# 223         NaN  208                  Steelix   Steel   Ground    510   75
# 224         NaN  208      SteelixMega Steelix   Steel   Ground    610   75
# 268         NaN  248  TyranitarMega Tyranitar    Rock     Dark    700  100
# 332         NaN  306                   Aggron   Steel     Rock    530   70
# 333         NaN  306        AggronMega Aggron   Steel      NaN    630   70
# 413         NaN  376  MetagrossMega Metagross   Steel  Psychic    700   80
# 414         NaN  377                 Regirock    Rock      NaN    580   80
# 424         NaN  383    GroudonPrimal Groudon  Ground     Fire    770  100
# 749         NaN  680                 Doublade   Steel    Ghost    448   59
# 789         NaN  713                  Avalugg     Ice      NaN    514   95
# ...

# %% [markdown]
# Outro critério de Filtro para as informações

# %%
df["Indice de força"] = df['Attack'] + df['Defense']+ df['Speed']

# %% [markdown]
# ## Operação entre colunas

# %%
df.sort_values(by = "Indice de força", ascending = False)
# Out:
#      Unnamed: 0    #                     Name   Type 1    Type 2  Total   HP  \
# 424         NaN  383    GroudonPrimal Groudon   Ground      Fire    770  100
# 333         NaN  306        AggronMega Aggron    Steel       NaN    630   70
# 163         NaN  150      MewtwoMega Mewtwo X  Psychic  Fighting    780  106
# 413         NaN  376  MetagrossMega Metagross    Steel   Psychic    700   80
# 409         NaN  373  SalamenceMega Salamence   Dragon    Flying    700   95
# ..          ...  ...                      ...      ...       ...    ...  ...
# 261         NaN  242                  Blissey   Normal       NaN    540  255
# 187         NaN  173                   Cleffa    Fairy       NaN    218   50
# 188         NaN  174                Igglybuff   Normal     Fairy    210   90
# 121         NaN  113                  Chansey   Normal       NaN    450  250
# 488         NaN  440                  Happiny   Normal       NaN    220  100
#
# ...

# %% [markdown]
# #Pegando o maior valor do indíce de força.

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6],'C': [7, 8, 9]})

# %% [markdown]
# #Utilizando o método iloc para selecionar uma linhaespecífica:
#
# # criando um DataFrame

# %%
inha = df.iloc[1]

# %% [markdown]
# #selecionando a segunda linha (índice 1) usando o método iloc

# %%
df
# Out:
#    A  B  C
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %% [markdown]
# #Digite a variável usada anteriormente, para exibir o resultado dos filtros

# %%
from os import linesep
linhas = df.iloc[[0, 2]]
print(linesep)

# %%
valor = df.iloc[1, 0]
print(valor)
# Out:
# 2

# %%
df = pd.DataFrame({'A': [1, 2, 3], 'B': [4, 5, 6],
'C': [7, 8, 9]}, index=['a', 'b', 'c'])

# %% [markdown]
# # criando um DataFrame com índices

# %%
linha = df.loc['b']
print(linha)
# Out:
# A    2
# B    5
# C    8
# Name: b, dtype: int64

# %% [markdown]
# # selecionando a linha de índice 'b' usando o método loc

# %%
df
# Out:
#    A  B  C
# a  1  4  7
# b  2  5  8
# c  3  6  9

# %%
linhas = df.loc[['a', 'c']]
print(linhas)
# Out:
#    A  B  C
# a  1  4  7
# c  3  6  9

# %% [markdown]
# # selecionando as linhas de índice 'a' e 'c' usando o método loc

# %%
linhas = df.loc[df['A'] > 1]
print(linhas)
# Out:
#    A  B  C
# b  2  5  8
# c  3  6  9

# %% [markdown]
# # selecionando as linhas onde o valor da coluna 'A' é maior que 1 usando o método loc

# %%
df
# Out:
#    A  B  C
# a  1  4  7
# b  2  5  8
# c  3  6  9

# %%
df = pd.read_excel('meu_arquivo.xlsx')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-163a08fa089a> in <cell line: 1>()
# ----> 1 df = pd.read_excel('meu_arquivo.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df
# Out:
#    A  B  C
# a  1  4  7
# b  2  5  8
# c  3  6  9

# %%
tabela_wiki = pd.read_html('https://en.wikipedia.org/wiki/Minnesota')

# %% [markdown]
# # Lendo arquivos HTML

# %%
tabela_wiki_temperatura =pd.read_html('https://en.wikipedia.org/wiki/Minnesota', match='Average daily maximum and minimum temperatures for selected cities in Minnesota')

# %%
tabela_wiki_temperatura[0]
# Out:
#               Location July (°F) July (°C) January (°F) January (°C)
# 0          Minneapolis     83/64     28/18         23/7       −4/−13
# 1           Saint Paul     83/63     28/17         23/6       −5/−14
# 2            Rochester     82/63     28/17         23/3       −5/−16
# 3               Duluth     76/55     24/13         19/1       −7/−17
# 4            St. Cloud     81/58     27/14        18/−1       −7/−18
# 5              Mankato     86/62     30/16         23/3       −5/−16
# 6  International Falls     77/52     25/11        15/−6       −9/−21

# %%
dados = [[1, 'João', 'São Paulo'], [2, 'Maria', 'Rio de Janeiro'], [3,
'José', 'Belo Horizonte']]

# %% [markdown]
# # criando uma lista de dados

# %%
df = pd.DataFrame(dados, columns=['id', 'nome', 'cidade'])

# %% [markdown]
# # criando um DataFrame a partir da lista

# %%
df
# Out:
#    id   nome          cidade
# 0   1   João       São Paulo
# 1   2  Maria  Rio de Janeiro
# 2   3   José  Belo Horizonte

# %%
dados = {'id': [1, 2, 3], 'nome': ['João', 'Maria', 'José'], 'cidade':
['São Paulo', 'Rio de Janeiro', 'Belo Horizonte']}

# %% [markdown]
# # criando um dicionário de dados

# %%
df = pd.DataFrame(dados)

# %% [markdown]
# # criando um DataFrame a partir do dicionário

# %%
df.head()
# Out:
#    id   nome          cidade
# 0   1   João       São Paulo
# 1   2  Maria  Rio de Janeiro
# 2   3   José  Belo Horizonte

# %%
dados = [{'id': 1, 'nome': 'João', 'cidade': 'São Paulo'}, {'id': 2,
'nome': 'Maria', 'cidade': 'Rio de Janeiro'}, {'id': 3, 'nome': 'José',
'cidade': 'Belo Horizonte'}]

# %% [markdown]
# # criando uma lista de dicionários

# %%
df = pd.DataFrame(dados)

# %% [markdown]
# # criando um DataFrame a partir da lista de dicionários

# %%
df.head()
# Out:
#    id   nome          cidade
# 0   1   João       São Paulo
# 1   2  Maria  Rio de Janeiro
# 2   3   José  Belo Horizonte
